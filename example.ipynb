# %% [markdown]
# **Automatic Speech Recognition**

# %%
from app.asr import ParaformerStreaming

import soundfile
    
chunk_ms = 480
sampling_rate = 16000
chunk_frames = int(chunk_ms * sampling_rate / 1000)

p = ParaformerStreaming(
    chunk_ms = chunk_ms)

wav_file = '/data1/wanghuan/audio_services/cache/asr_example.wav'
speech, _ = soundfile.read(wav_file)

total_chunk_num = int(len((speech)-1)/chunk_frames+1)
for i in range(total_chunk_num):
    speech_chunk = speech[i*chunk_frames:(i+1)*chunk_frames]
    is_final = i == total_chunk_num - 1
    res = p.run(speech_chunk, sampling_rate=sampling_rate, is_final = is_final)
# Out:
# rtf_avg: 0.127: 100%|██████████| 1/1 [00:00<00:00, 15.60it/s]
# [{'key': 'rand_key_1qeoePtwBldGD', 'text': ''}]
# rtf_avg: 0.101: 100%|██████████| 1/1 [00:00<00:00, 19.49it/s]
# [{'key': 'rand_key_cMgSzmqw5UE15', 'text': ''}]
# rtf_avg: 0.144: 100%|██████████| 1/1 [00:00<00:00, 13.78it/s]
# [{'key': 'rand_key_6KkSRn9XdYRk2', 'text': '欢'}]
# rtf_avg: 0.135: 100%|██████████| 1/1 [00:00<00:00, 14.82it/s]
# [{'key': 'rand_key_kvHqhM6CQlaER', 'text': '迎大'}]
# rtf_avg: 0.135: 100%|██████████| 1/1 [00:00<00:00, 14.69it/s]
# [{'key': 'rand_key_A5K3G6tPwy1Qq', 'text': '家来体'}]
# rtf_avg: 0.132: 100%|██████████| 1/1 [00:00<00:00, 15.18it/s]
# [{'key': 'rand_key_jJSaDVfvVcIri', 'text': '验达'}]
# rtf_avg: 0.132: 100%|██████████| 1/1 [00:00<00:00, 15.23it/s]
# [{'key': 'rand_key_pW9EwNsRwL85O', 'text': '摩院'}]
# rtf_avg: 0.127: 100%|██████████| 1/1 [00:00<00:00, 15.60it/s]
# [{'key': 'rand_key_2NiTtyVA1PfaM', 'text': '推出'}]
# rtf_avg: 0.146: 100%|██████████| 1/1 [00:00<00:00, 13.47it/s]
# [{'key': 'rand_key_mSvkpoOCyT4RK', 'text': '的语'}]
# rtf_avg: 0.140: 100%|██████████| 1/1 [00:00<00:00, 13.97it/s]
# [{'key': 'rand_key_3Acz3SKAXQTck', 'text': '音识'}]
# rtf_avg: 0.158: 100%|██████████| 1/1 [00:00<00:00, 12.49it/s]
# [{'key': 'rand_key_CeqSkCH4F6JMW', 'text': '别模'}]
# rtf_avg: 0.261: 100%|██████████| 1/1 [00:00<00:00, 12.24it/s]
# [{'key': 'rand_key_a4cFut1DdZ04Z', 'text': '型'}]

# %% [markdown]
# **Voice Activity Detection**

# %%
from app.vad import FMSNVad
import soundfile

chunk_seconds = 480

audio_data, sampling_rate = soundfile.read("/data1/wanghuan/audio_services/cache/asr_example.wav")
vad = FMSNVad()


wav_file = f"/data1/wanghuan/audio_services/cache/asr_example.wav"
speech, sample_rate = soundfile.read(wav_file)
chunk_stride = int(chunk_seconds * sample_rate / 1000)

results = []
total_chunk_num = int(len((speech)-1)/chunk_stride+1)
for i in range(total_chunk_num):
    if i == total_chunk_num -1:
        is_final = True
    else:
        is_final = False
    speech_chunk = speech[i*chunk_stride:(i+1)*chunk_stride]
    res = vad.run(speech_chunk, is_final = is_final)
    results.append(res)
# Out:
# funasr version: 1.2.6.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# You are using the latest version of funasr-1.2.6
# 2025-04-02 17:13:33,640 - modelscope - INFO - Use user-specified model revision: v2.0.4
# rtf_avg: 0.381: 100%|██████████| 1/1 [00:00<00:00,  5.89it/s]
# rtf_avg: 0.013: 100%|██████████| 1/1 [00:00<00:00, 126.40it/s]
# rtf_avg: 0.015: 100%|██████████| 1/1 [00:00<00:00, 114.92it/s]
# rtf_avg: 0.012: 100%|██████████| 1/1 [00:00<00:00, 135.38it/s]
# rtf_avg: 0.013: 100%|██████████| 1/1 [00:00<00:00, 132.22it/s]
# rtf_avg: 0.013: 100%|██████████| 1/1 [00:00<00:00, 127.57it/s]
# rtf_avg: 0.013: 100%|██████████| 1/1 [00:00<00:00, 130.88it/s]
# rtf_avg: 0.014: 100%|██████████| 1/1 [00:00<00:00, 118.84it/s]
# rtf_avg: 0.012: 100%|██████████| 1/1 [00:00<00:00, 145.73it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 151.84it/s]
# rtf_avg: 0.014: 100%|██████████| 1/1 [00:00<00:00, 124.58it/s]
# rtf_avg: 0.575: 100%|██████████| 1/1 [00:00<00:00, 72.74it/s]

# %%
results
# Out:
# [[{'key': 'rand_key_2yW4Acq9GFz6Y', 'value': []}],
#  [{'key': 'rand_key_1t9EwL56nGisi', 'value': []}],
#  [{'key': 'rand_key_WgNZq6ITZM5jt', 'value': [[610, -1]]}],
#  [{'key': 'rand_key_gUe52RvEJgwBu', 'value': []}],
#  [{'key': 'rand_key_NO6n9JEC3HqdZ', 'value': []}],
#  [{'key': 'rand_key_6J6afU1zT0YQO', 'value': []}],
#  [{'key': 'rand_key_aNF03vpUuT3em', 'value': []}],
#  [{'key': 'rand_key_6KopZ9jZICffu', 'value': []}],
#  [{'key': 'rand_key_4G7FgtJsThJv0', 'value': []}],
#  [{'key': 'rand_key_7In9ZMJLsCfMZ', 'value': []}],
#  [{'key': 'rand_key_yuKpslm0lcNQq', 'value': []}],
#  [{'key': 'rand_key_EefRWi4j7c1f5', 'value': [[-1, 5530]]}]]

# %%
from app.asr import ParaformerStreaming
from app.vad import FMSNVad
import soundfile
    
chunk_ms = 600
sampling_rate = 16000
chunk_frames = int(chunk_ms * sampling_rate / 1000)

p = ParaformerStreaming(
    chunk_ms = chunk_ms)

vad = FMSNVad()

wav_file = '/data1/wanghuan/audio_services/cache/recording.wav'
speech, _ = soundfile.read(wav_file)

stream_cache = []
cache = []
total_chunk_num = int(len((speech)-1)/chunk_frames+1)

for i in range(total_chunk_num):
    speech_chunk = speech[i*chunk_frames:(i+1)*chunk_frames]
    is_final = i == total_chunk_num - 1
    res = p.run(speech_chunk, sampling_rate=sampling_rate, is_final = is_final)
    cache.append(res)
    stream_cache.append(res)
    
    if vad.vad(speech_chunk, sample_rate = sampling_rate, is_final = is_final):
        t = [v[0]['text'] for v in cache]
        print("".join(t))
        cache = []
        
if len(cache) > 0:
    t = [v[0]['text'] for v in cache]       
    print("".join(t))
# Out:
# rtf_avg: 0.100: 100%|██████████| 1/1 [00:00<00:00, 16.03it/s]
# rtf_avg: 0.014: 100%|██████████| 1/1 [00:00<00:00, 101.73it/s]
# rtf_avg: 0.093: 100%|██████████| 1/1 [00:00<00:00, 17.06it/s]
# rtf_avg: 0.012: 100%|██████████| 1/1 [00:00<00:00, 111.77it/s]
# rtf_avg: 0.123: 100%|██████████| 1/1 [00:00<00:00, 13.08it/s]
# rtf_avg: 0.012: 100%|██████████| 1/1 [00:00<00:00, 102.26it/s]
# rtf_avg: 0.127: 100%|██████████| 1/1 [00:00<00:00, 12.68it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 112.75it/s]
# rtf_avg: 0.095: 100%|██████████| 1/1 [00:00<00:00, 16.81it/s]
# rtf_avg: 0.012: 100%|██████████| 1/1 [00:00<00:00, 105.42it/s]
# 你好你好
# rtf_avg: 0.122: 100%|██████████| 1/1 [00:00<00:00, 13.21it/s]
# rtf_avg: 0.012: 100%|██████████| 1/1 [00:00<00:00, 105.72it/s]
# rtf_avg: 0.122: 100%|██████████| 1/1 [00:00<00:00, 13.26it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 111.62it/s]
# rtf_avg: 0.120: 100%|██████████| 1/1 [00:00<00:00, 13.48it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 117.47it/s]
# rtf_avg: 0.091: 100%|██████████| 1/1 [00:00<00:00, 17.50it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 112.01it/s]
# rtf_avg: 0.122: 100%|██████████| 1/1 [00:00<00:00, 13.26it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 118.37it/s]
# rtf_avg: 0.123: 100%|██████████| 1/1 [00:00<00:00, 13.15it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 114.64it/s]
# rtf_avg: 0.121: 100%|██████████| 1/1 [00:00<00:00, 13.36it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 119.84it/s]
# rtf_avg: 0.092: 100%|██████████| 1/1 [00:00<00:00, 17.40it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 112.64it/s]
# 今天你开心吗你们公司有什么产品
# rtf_avg: 0.122: 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 109.24it/s]
# rtf_avg: 0.122: 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 117.87it/s]
# rtf_avg: 0.118: 100%|██████████| 1/1 [00:00<00:00, 13.64it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 119.91it/s]
# rtf_avg: 0.228: 100%|██████████| 1/1 [00:00<00:00, 14.02it/s]
# 你们公司是做金融的吗

# %%
from funasr import AutoModel
from functools import lru_cache
from dataclasses import dataclass

@lru_cache(maxsize=None)
def load_punc_model():
    return AutoModel(model="ct-punc", model_revision="v2.0.4")

@dataclass
class PunctuationModel:

    def __post_init__(self):
        self.model = load_punc_model()
        
    def run(self, text:str):
        return self.model.generate(input=text)[0]['text']

# %%
from dataclasses import dataclass
import soundfile
from app.asr import ParaformerStreaming
from app.vad import FMSNVad

@dataclass
class AudioInputPipeline:
    
    chunk_ms: int = 600
    
    def __post_init__(self):
        self.vad = FMSNVad()
        self.asr = ParaformerStreaming(chunk_ms=chunk_ms)
        self.punc_model = PunctuationModel()
        self.stream_cache = []
        self.temp_cache = []
        self.chunk_id = 0
        
    def parse(
        self, 
        speech_chunk, 
        sampling_rate = 16000, 
        is_final = False):
        
        asr_result = self.asr.run(
            speech_chunk, 
            sampling_rate=sampling_rate, 
            is_final = is_final)
        
        # vad缓存
        self.temp_cache.append(asr_result)
        
        # 整体缓存
        self.stream_cache.append(asr_result)
        
        if self.vad.vad(
            speech_chunk, 
            sample_rate = sampling_rate, 
            is_final = is_final):
            
            t = [v[0]['text'] for v in self.temp_cache]
            output = "".join(t)
            # 重置vad缓存
            self.temp_cache = []
            return self.punc_model.run(output)
        
        return None

# %%
import soundfile
from app.pipeline.audio_input_pipe import AudioInputPipeline
pipe = AudioInputPipeline()
# Out:
# funasr version: 1.2.6.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# You are using the latest version of funasr-1.2.6
# 2025-04-02 21:09:24,077 - modelscope - INFO - Use user-specified model revision: v2.0.4
# funasr version: 1.2.6.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# You are using the latest version of funasr-1.2.6
# 2025-04-02 21:09:40,875 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# funasr version: 1.2.6.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# You are using the latest version of funasr-1.2.6
# 2025-04-02 21:09:47,072 - modelscope - INFO - Use user-specified model revision: v2.0.4
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# DEBUG:jieba:Loading model from cache /tmp/jieba.cache
# Loading model cost 0.593 seconds.
# DEBUG:jieba:Loading model cost 0.593 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %%
chunk_ms = 600
sampling_rate = 16000
chunk_frames = int(chunk_ms * sampling_rate / 1000)

wav_file = '/data1/wanghuan/audio_services/cache/recording.wav'
speech, _ = soundfile.read(wav_file)
chunk_stride = int(chunk_ms * sampling_rate / 1000)
total_chunk_num = int(len((speech)-1)/chunk_stride+1)

for i in range(total_chunk_num):
    speech_chunk = speech[i*chunk_frames:(i+1)*chunk_frames]
    res = pipe.parse(speech_chunk, sampling_rate=sampling_rate, is_final = False)
    print("输出结果：", res)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# rtf_avg: 0.554: 100%|██████████| 1/1 [00:00<00:00,  2.97it/s]
# rtf_avg: 0.013: 100%|██████████| 1/1 [00:00<00:00, 102.50it/s]
# 输出结果： {'chunk_id': 2, 'start_time': 0, 'end_time': 600, 'text': '', 'is_partial': True}
# rtf_avg: 0.081: 100%|██████████| 1/1 [00:00<00:00, 19.47it/s]
# rtf_avg: 0.011: 100%|██████████| 1/1 [00:00<00:00, 110.43it/s]
# 输出结果： {'chunk_id': 3, 'start_time': 600, 'end_time': 1200, 'text': '', 'is_partial': True}
# rtf_avg: 0.120: 100%|██████████| 1/1 [00:00<00:00, 13.09it/s]
# rtf_avg: 0.010: 100%|██████████| 1/1 [00:00<00:00, 113.22it/s]
# 输出结果： {'chunk_id': 4, 'start_time': 1200, 'end_time': 1800, 'text': '你好你', 'is_partial': True}
# rtf_avg: 0.114: 100%|██████████| 1/1 [00:00<00:00, 14.03it/s]
# rtf_avg: 0.013: 100%|██████████| 1/1 [00:00<00:00, 101.99it/s]
# 输出结果： {'chunk_id': 5, 'start_time': 1800, 'end_time': 2400, 'text': '好', 'is_partial': True}
# rtf_avg: 0.071: 100%|██████████| 1/1 [00:00<00:00, 22.00it/s]
# rtf_avg: 0.009: 100%|██████████| 1/1 [00:00<00:00, 124.73it/s]
# rtf_avg: -0.382: 100%|██████████| 1/1 [00:00<00:00,  2.59it/s]
# 输出结果： {'chunk_id': 6, 'start_time': 2400, 'end_time': 3000, 'text': '你好你好。', 'is_partial': False}
# rtf_avg: 0.091: 100%|██████████| 1/1 [00:00<00:00, 17.47it/s]
# rtf_avg: 0.010: 100%|██████████| 1/1 [00:00<00:00, 118.97it/s]
# 输出结果： {'chunk_id': 7, 'start_time': 3000, 'end_time': 3600, 'text': '今', 'is_partial': True}
# rtf_avg: 0.090: 100%|██████████| 1/1 [00:00<00:00, 17.58it/s]
# rtf_avg: 0.009: 100%|██████████| 1/1 [00:00<00:00, 123.09it/s]
# 输出结果： {'chunk_id': 8, 'start_time': 3600, 'end_time': 4200, 'text': '天你开', 'is_partial': True}
# rtf_avg: 0.092: 100%|██████████| 1/1 [00:00<00:00, 17.30it/s]
# rtf_avg: 0.008: 100%|██████████| 1/1 [00:00<00:00, 131.00it/s]
# 输出结果： {'chunk_id': 9, 'start_time': 4200, 'end_time': 4800, 'text': '心吗', 'is_partial': True}
# rtf_avg: 0.070: 100%|██████████| 1/1 [00:00<00:00, 22.40it/s]
# rtf_avg: 0.009: 100%|██████████| 1/1 [00:00<00:00, 126.54it/s]
# 输出结果： {'chunk_id': 10, 'start_time': 4800, 'end_time': 5400, 'text': '', 'is_partial': True}
# rtf_avg: 0.087: 100%|██████████| 1/1 [00:00<00:00, 18.42it/s]
# rtf_avg: 0.008: 100%|██████████| 1/1 [00:00<00:00, 151.02it/s]
# 输出结果： {'chunk_id': 11, 'start_time': 5400, 'end_time': 6000, 'text': '你们公司有', 'is_partial': True}
# rtf_avg: 0.088: 100%|██████████| 1/1 [00:00<00:00, 18.27it/s]
# rtf_avg: 0.008: 100%|██████████| 1/1 [00:00<00:00, 145.04it/s]
# 输出结果： {'chunk_id': 12, 'start_time': 6000, 'end_time': 6600, 'text': '什么产', 'is_partial': True}
# rtf_avg: 0.086: 100%|██████████| 1/1 [00:00<00:00, 18.60it/s]
# rtf_avg: 0.008: 100%|██████████| 1/1 [00:00<00:00, 154.16it/s]
# 输出结果： {'chunk_id': 13, 'start_time': 6600, 'end_time': 7200, 'text': '品', 'is_partial': True}
# rtf_avg: 0.064: 100%|██████████| 1/1 [00:00<00:00, 24.74it/s]
# rtf_avg: 0.009: 100%|██████████| 1/1 [00:00<00:00, 136.07it/s]
# rtf_avg: -0.011: 100%|██████████| 1/1 [00:00<00:00, 76.40it/s]
# 输出结果： {'chunk_id': 14, 'start_time': 7200, 'end_time': 7800, 'text': '今天你开心吗？你们公司有什么产品？', 'is_partial': False}
# rtf_avg: 0.086: 100%|██████████| 1/1 [00:00<00:00, 18.59it/s]
# rtf_avg: 0.009: 100%|██████████| 1/1 [00:00<00:00, 142.61it/s]
# 输出结果： {'chunk_id': 15, 'start_time': 7800, 'end_time': 8400, 'text': '你', 'is_partial': True}
# rtf_avg: 0.086: 100%|██████████| 1/1 [00:00<00:00, 18.73it/s]
# rtf_avg: 0.008: 100%|██████████| 1/1 [00:00<00:00, 153.60it/s]
# 输出结果： {'chunk_id': 16, 'start_time': 8400, 'end_time': 9000, 'text': '们公司是', 'is_partial': True}
# rtf_avg: 0.087: 100%|██████████| 1/1 [00:00<00:00, 18.39it/s]
# rtf_avg: 0.008: 100%|██████████| 1/1 [00:00<00:00, 150.18it/s]
# 输出结果： {'chunk_id': 17, 'start_time': 9000, 'end_time': 9600, 'text': '做金融', 'is_partial': True}
# rtf_avg: -0.000: 100%|██████████| 1/1 [00:00<00:00, 297.83it/s]
# 输出结果： {'chunk_id': 18, 'start_time': 9600, 'end_time': 10200, 'text': '', 'is_partial': True}
