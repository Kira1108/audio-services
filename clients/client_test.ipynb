# %%
import asyncio
import nest_asyncio
import websockets
import json
import soundfile
import time

nest_asyncio.apply()

URI = "ws://localhost:7890/asr/streaming/pipeline"

async def send_audio_chunks(websocket, speech, chunk_frames: int = 9600):
    total_chunk_num = int(len(speech) - 1) // chunk_frames + 1
    for i in range(total_chunk_num):
        await asyncio.sleep(0.6)
        speech_chunk = speech[i * chunk_frames:(i + 1) * chunk_frames]
        data = {
            "chunk": speech_chunk.tolist(),
            "status": "processing",
            "is_final": i == total_chunk_num - 1
        }
        await websocket.send(json.dumps(data))
        print(f"Sent: success {str(speech_chunk[:5])}...")  # Print first 5 samples for brevity
        

    # Send end message
    end_message = {"status": "end", "chunk": []}
    await websocket.send(json.dumps(end_message))
    print(f"Sent: {end_message}")

async def receive_responses(websocket):
    results = []
    while True:
        try:
            response = await websocket.recv()
            response = json.loads(response)
            results.append({
                "action": "receive",
                "timestamp": time.time(),
                "data": response,
                "text": response.get("text", ""),
                "is_partial": response.get("is_partial", False)
            })
            print(f"Received: {response}")
        except websockets.ConnectionClosed:
            print("WebSocket connection closed.")
            break
    return results

async def stream_asr(speech, chunk_frames: int = 9600):
    async with websockets.connect(URI) as websocket:
        # Run send_audio_chunks and receive_responses concurrently
        send_task = send_audio_chunks(websocket, speech, chunk_frames)
        receive_task = receive_responses(websocket)
        results = await asyncio.gather(send_task, receive_task)
    return results[1]  # Return the results from receive_responses

if __name__ == "__main__":

    wav_file = '/data1/wanghuan/audio_services/cache/recording.wav'
    speech, _ = soundfile.read(wav_file)
    res = asyncio.run(stream_asr(speech))
    print('Got result', res)
# Out:
# Sent: success [0. 0. 0. 0. 0.]...
# Sent: success [0. 0. 0. 0. 0.]...
# Sent: success [ 0.16900635  0.31655884 -0.48492432 -0.35516357  0.07397461]...
# Sent: success [ 0.00326538  0.0012207  -0.00137329 -0.00039673  0.0005188 ]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 1, 'start_time': 0, 'end_time': 600, 'text': '', 'is_partial': True}
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 2, 'start_time': 600, 'end_time': 1200, 'text': '', 'is_partial': True}
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 3, 'start_time': 1200, 'end_time': 1800, 'text': '你好你', 'is_partial': True}
# Sent: success [ 0.00030518  0.00024414 -0.00018311 -0.00021362  0.        ]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 4, 'start_time': 1800, 'end_time': 2400, 'text': '好', 'is_partial': True}
# Sent: success [-6.10351562e-05 -9.15527344e-04 -1.15966797e-03  1.83105469e-04
#   6.71386719e-04]...
# Sent: success [-0.00048828  0.01647949  0.00576782 -0.00958252 -0.00531006]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 5, 'start_time': 2400, 'end_time': 3000, 'text': '你好你好。。', 'is_partial': False}
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 6, 'start_time': 3000, 'end_time': 3600, 'text': '今', 'is_partial': True}
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 7, 'start_time': 3600, 'end_time': 4200, 'text': '天你开心', 'is_partial': True}
# Sent: success [-0.00067139 -0.00360107  0.00018311  0.00256348 -0.00039673]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 8, 'start_time': 4200, 'end_time': 4800, 'text': '吗', 'is_partial': True}
# Sent: success [-6.10351562e-05 -3.05175781e-05 -9.15527344e-05 -6.10351562e-05
#  -3.05175781e-05]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 9, 'start_time': 4800, 'end_time': 5400, 'text': '', 'is_partial': True}
# Sent: success [-0.1265564  -0.1144104  -0.11251831 -0.10583496 -0.08987427]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 10, 'start_time': 5400, 'end_time': 6000, 'text': '你们公司有', 'is_partial': True}
# Sent: success [-0.15853882 -0.11883545 -0.02658081  0.01052856  0.07543945]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 11, 'start_time': 6000, 'end_time': 6600, 'text': '什么产', 'is_partial': True}
# Sent: success [-0.00067139  0.          0.0007019   0.00094604  0.00045776]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 12, 'start_time': 6600, 'end_time': 7200, 'text': '品', 'is_partial': True}
# Sent: success [-3.05175781e-05 -6.10351562e-05 -6.10351562e-05  3.05175781e-05
#   6.10351562e-05]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 13, 'start_time': 7200, 'end_time': 7800, 'text': '今天你开心吗？？，你们公司有什么产品？？？', 'is_partial': False}
# Sent: success [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.05175781e-05]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 14, 'start_time': 7800, 'end_time': 8400, 'text': '你', 'is_partial': True}
# Sent: success [-0.01797485  0.01196289 -0.09912109 -0.01498413 -0.0055542 ]...
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 15, 'start_time': 8400, 'end_time': 9000, 'text': '们公司是', 'is_partial': True}
# Sent: success [-0.22946167 -0.16278076 -0.1008606  -0.06289673 -0.03915405]...
# Sent: {'status': 'end', 'chunk': []}
# Received: {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 16, 'start_time': 9000, 'end_time': 9600, 'text': '你们公司是做金融的吗？？。', 'is_partial': False}
# WebSocket connection closed.
# Got result [{'action': 'receive', 'timestamp': 1746513621.0885901, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 1, 'start_time': 0, 'end_time': 600, 'text': '', 'is_partial': True}, 'text': '', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513621.1671917, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 2, 'start_time': 600, 'end_time': 1200, 'text': '', 'is_partial': True}, 'text': '', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513621.471182, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 3, 'start_time': 1200, 'end_time': 1800, 'text': '你好你', 'is_partial': True}, 'text': '你好你', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513621.5724862, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 4, 'start_time': 1800, 'end_time': 2400, 'text': '好', 'is_partial': True}, 'text': '好', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513622.965561, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 5, 'start_time': 2400, 'end_time': 3000, 'text': '你好你好。。', 'is_partial': False}, 'text': '你好你好。。', 'is_partial': False}, {'action': 'receive', 'timestamp': 1746513623.1989791, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 6, 'start_time': 3000, 'end_time': 3600, 'text': '今', 'is_partial': True}, 'text': '今', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513623.2651331, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 7, 'start_time': 3600, 'end_time': 4200, 'text': '天你开心', 'is_partial': True}, 'text': '天你开心', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513623.5598924, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 8, 'start_time': 4200, 'end_time': 4800, 'text': '吗', 'is_partial': True}, 'text': '吗', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513624.096166, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 9, 'start_time': 4800, 'end_time': 5400, 'text': '', 'is_partial': True}, 'text': '', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513624.7673595, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 10, 'start_time': 5400, 'end_time': 6000, 'text': '你们公司有', 'is_partial': True}, 'text': '你们公司有', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513625.4576285, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 11, 'start_time': 6000, 'end_time': 6600, 'text': '什么产', 'is_partial': True}, 'text': '什么产', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513626.09021, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 12, 'start_time': 6600, 'end_time': 7200, 'text': '品', 'is_partial': True}, 'text': '品', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513627.0635095, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 13, 'start_time': 7200, 'end_time': 7800, 'text': '今天你开心吗？？，你们公司有什么产品？？？', 'is_partial': False}, 'text': '今天你开心吗？？，你们公司有什么产品？？？', 'is_partial': False}, {'action': 'receive', 'timestamp': 1746513627.359266, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 14, 'start_time': 7800, 'end_time': 8400, 'text': '你', 'is_partial': True}, 'text': '你', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513627.9009843, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 15, 'start_time': 8400, 'end_time': 9000, 'text': '们公司是', 'is_partial': True}, 'text': '们公司是', 'is_partial': True}, {'action': 'receive', 'timestamp': 1746513629.131117, 'data': {'conversation_id': '8ccada5c-0df7-4cb9-9432-d53e42c0aecf', 'chunk_id': 16, 'start_time': 9000, 'end_time': 9600, 'text': '你们公司是做金融的吗？？。', 'is_partial': False}, 'text': '你们公司是做金融的吗？？。', 'is_parti ...
